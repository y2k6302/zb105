# %%
a = 'apple'
print a=='apple'
# Out:
# True

# %% [markdown]
# ## 比對單一英文字母
# 1. re.match('比對條件' , '比對的東西')
# 2. [ ]是或的概念
# 3. [a-z] = [abcdefg......z]
# 4. [a-zA-Z] 大小寫會有差

# %%
import re
word = 'a'
m = re.match('a', word) # match word
print m
m = re.match('b', word) # match none
print m
# Out:
# <_sre.SRE_Match object at 0x0000000003A85C60>
# None

# %%
#[]是或的概念
#寫法一，後面一定要有else
word = 'z' 
print word if re.match('[a-z]',word) else none
#寫法二
word = 'z' 
m = re.match('[a-zA-Z]',word)
if m :
    print word
# Out:
# z
# z

# %% [markdown]
# ## 比對單一數字
# 1. re.match()似乎只能用來比對str
# 2. 所以"數字"可能也要變成"字串型態"

# %%
n='8'
print n if re.match('8',n) else none # match 8
print n if re.match('[0123456789]',n) else none# match either numeric
print n if re.match('[0-9]',n) else none
print type()
# Out:
# 8
# 8
# 8
# <type 'str'>

# %% [markdown]
# ## 比對多個文字(要抓固定長度)
# 1. 要連續寫多個迴圈最外面要包[ ]
# 2. {4} 出現4次
# 3. {4,5} 最少4次最多5次

# %%
 # the first three are true caid
carid = ['1122-AB', '2222-QQ', '3333-QG', 'A92B-12', '3A4B-1L', '12345-AAA']
print [ele for ele in carid if re.match('[0-9]',ele)] #anything that has a numeric as initial word
print [ele for ele in carid if re.match('[0-9]{4}-[a-zA-Z]{2}',ele)] # anything that matches to NNNN-AA
# anything that matches to NNNN-AA or NNNNN-AAA
print [ ele  for ele in carid if re.match('[0-9]{4,5}-[A-Z]{2,3}', ele)]
# Out:
# ['1122-AB', '2222-QQ', '3333-QG', '3A4B-1L', '12345-AAA']
# ['1122-AB', '2222-QQ', '3333-QG']
# ['1122-AB', '2222-QQ', '3333-QG', '12345-AAA']

# %% [markdown]
# ## 比對多個文字 (不固定長度 e.g. EMAIL)
# 1. 要比對固定長度就要用{} or + or *
# 2. \.  \是跳脫字元的意思，所以是告訴程式 . 是有意義的

# %%
email = ['qoo@cocacola.com', 'anonymous@111.22', '13u1udhfgiudhi-sldfjsdjfos', 'acool123@pchome.com.tw']
# anything that matchs *@*.com
print [ ele  for ele in email if re.match('[a-zA-Z]{1,}@[a-z]{0,}\.com', ele)] 
print [ ele  for ele in email if re.match('[a-zA-Z]+@[a-z]*\.com', ele)] # {1,} == +,  {0,} == *
print [ ele  for ele in email if re.match('[a-zA-Z0-9]+@[a-zA-Z.]+', ele)]
print [ ele  for ele in email if re.match('\w+@.+',ele)] #[a-zA-Z0-9] == \w, anything == .
# Out:
# ['qoo@cocacola.com']
# ['qoo@cocacola.com']
# ['qoo@cocacola.com', 'acool123@pchome.com.tw']
# ['qoo@cocacola.com', 'anonymous@111.22', 'acool123@pchome.com.tw']

# %% [markdown]
# ## 比對電話號碼
# 1. {0,1} == ?
# 2. [0-9] == \d
# 3. [a-zA-Z0-9] == \w

# %%
phone = ['0912345678', '0923-451-192', '0912-111222', '029310319301', '0912312318231310893010']
print [ ele  for ele in phone if re.match('[0-9]+', ele)] 
print [ ele  for ele in phone if re.match('09[0-9]{2}-{0,1}[0-9]{3}-{0,1}[0-9]{3}', ele)] 
print [ ele  for ele in phone if re.match('09[0-9]{2}-?[0-9]{3}-?[0-9]{3}', ele)] # {0,1} == ?
print [ ele  for ele in phone if re.match('09\d{2}-?\d{3}-?\d{3}', ele)] # [0-9] == \d, [a-zA-Z0-9] == \w

#電話比對完整版
print [ele for ele in phone if re.match('^09\d{2}-?\d{3}-?\d{3}$',ele)]
# Out:
# ['0912345678', '0923-451-192', '0912-111222', '029310319301', '0912312318231310893010']
# ['0912345678', '0923-451-192', '0912-111222', '0912312318231310893010']
# ['0912345678', '0923-451-192', '0912-111222', '0912312318231310893010']
# ['0912345678', '0923-451-192', '0912-111222', '0912312318231310893010']
# ['0912345678', '0923-451-192', '0912-111222']

# %% [markdown]
# ## 開頭與結尾比對

# %%
name = ['David', 'Jones', 'Amy', 'Linda', 'Johnson', 'Jenny']
print [] 

print [ ele  for ele in name if re.match('^J\w+', ele)] # use ^ to match any begin word
print [ ele  for ele in name if re.match('\w+y$', ele)] # use $ to match any end word
# Out:
# []
# ['Jones', 'Johnson', 'Jenny']
# ['Amy', 'Jenny']

# %% [markdown]
# ### 資料抽取    ?P<'name'>  (P要大寫，千萬記得)

# %%
# 用()包起來就是一個group
email = ['qoo@cocacola.com', 'anonymous@111.22', '13u1udhfgiudhi-sldfjsdjfos', 'acool123@pchome.com.tw']
for ele in email:
    m = re.match('(\w+)@(.+)',ele)     # 用()包起來就是一個group
    if m :
        #print m.group(1)               #印出第一個group
        #print m.group(0)               #group(0) print everything
        username,hostname = m.group(1),m.group(2) #替group設名稱
        print username,hostname
# Out:
# qoo cocacola.com
# anonymous 111.22
# acool123 pchome.com.tw

# %%
# ?P<'name'> 直接替group設名稱  (P要記得大寫)
email = ['qoo@cocacola.com', 'anonymous@111.22', '13u1udhfgiudhi-sldfjsdjfos', 'acool123@pchome.com.tw']
for ele in email:
    m = re.match('(?P<username>\w+)@(?P<hostname>.+)',ele)  
    if m :
        print m.group('username'), m.group('hostname')
# Out:
# qoo cocacola.com
# anonymous 111.22
# acool123 pchome.com.tw

# %% [markdown]
# ## FB  API使用

# %%
import requests
import json
import jieba
dic = {}
jieba.add_word('蔡英文')
def update_dic(jd, dic):
    for entry in jd['data']:
        if 'message' in entry:
            for ele in jieba.cut(entry['message']):
                if not ele in dic:
                    dic[ele] = 1
                else:
                    dic[ele] = dic[ele] + 1

# ACCESS_TOKEN 要使用自己帳號登入產生的 
ACCESS_TOKEN = 'CAACEdEose0cBAIZBhVzKg5xNSANwV1piX9b699pGLJXd4cP5DbscWrFAhBtdqE49EfSjtLW1FZCrX1ZCuL8nmstEEvLzIPZCSofxPXhhFZBaJIIZA1zjb0aABg3g6KcdlSO2wPklW8pZAsilDPmBJaB0piz7vQ1LOqL8idDwfJST3oldF6F8HrhrUVw98Np7axpnLPOQGUL3iLr7zekxROM'
res = requests.get('https://graph.facebook.com/v2.5/tsaiingwen/posts?access_token={}&limit=100&since=1420070400'.format(ACCESS_TOKEN))
jd = json.loads(res.text)

update_dic(jd, dic)

#當有使用到 since 的條件時，才需要用到下面的page換頁
while 'paging' in jd and jd['paging']['next']:
    res = requests.get(jd['paging']['next'])
    jd = json.loads(res.text)
    update_dic(jd, dic)

# %%
from operator import itemgetter
import re
swd = sorted(dic.items(), key = itemgetter(1), reverse=True)
for ele in swd:
    if re.match(u'[\u4e00-\u9fa5]+', ele[0]) and len(ele[0]) >=2:
        print ele[0], ele[1]
# Out:
# 我們 964
# 台灣 831
# 改革 317
# 人民 311
# 民進黨 264
# 一個 236
# 支持 235
# 大家 231
# 未來 199
# 就是 188
# 一起 185
# 這個 182
# 立委 176
# 政府 173
# 民主 167
# 社會 161
# 英派 152
# 國家 150
# 改變 149
# 蔡英文 149
# 革新 142
# 好政 141
# 可以 137
# 政策 118
# 希望 116
# 一定 115
# 他們 113
# 國會 110
# 政黨 105
# 自己 102
# 總統 99
# 因為 98
# 推動 97
# 產業 96
# 選舉 95
# 發展 94
# 第一 93
# 過半 92
# 進步 92
# 政治 91
# 我要 88
# 努力 87
# 投票 87
# 沒有 84
# 一次 83
# 朋友 81
# 過去 81
# 客家 80
# 如果 77
# 點亮 76
# 但是 75
# 力量 75
# 計畫 74
# 經濟 72
# 這些 72
# 所有 71
# 執政 71
# 地方 70
# 重要 68
# 這裡 68
# 我會 67
# 不是 67
# 問題 66
# 開始 66
# 時候 66
# 主席 65
# 不會 65
# 很多 64
# 團結 63
# 不能 62
# 中央 62
# 現在 62
# 選票 61
# 謝謝 61
# 看到 59
# 必須 59
# 以及 57
# 已經 57
# 相信 57
# 名單 56
# 創新 55
# 國民黨 54
# 知道 54
# 共同 54
# 今天 53
# 生活 52
# 輕人 52
# 期待 52
# 這是 50
# 機會 49
# 環境 49
# 閱讀 49
# 需要 48
# 全國 48
# 分區 48
# 責任 48
# 鄉親 47
# 一步 46
# 直播 46
# 只是 46
# 這次 46
# 能夠 46
# 真正 46
# 文化 45
# 四年 45
# 代表 44
# 土地 44
# 應該 44
# 桃園 43
# 照顧 43
# 台南 43
# 五大 42
# 正義 41
# 事情 41
# 網路 41
# 還有 41
# 工作 41
# 這樣 40
# 感謝 40
# 企業 40
# 公平 40
# 建仁 40
# 決心 40
# 明天 39
# 合作 39
# 所以 39
# 得到 39
# 不同 39
# 成為 39
# 一直 38
# 國際 38
# 起來 38
# 轉型 38
# 專業 38
# 提出 38
# 透過 37
# 農業 37
# 行程 37
# 時代 37
# 一樣 36
# 苗栗 36
# 歷史 36
# 建立 36
# 更好 36
# 政黨票 36
# 投給 36
# 一票 35
# 時間 35
# 基隆 35
# 小豬 34
# 選擇 34
# 一天 34
# 返鄉 34
# 只要 34
# 市長 33
# 品牌 33
# 各位 33
# 出來 33
# 國會輪 33
# 非常 33
# 完成 33
# 選區 32
# 研發 32
# 台三線 32
# 什麼 32
# 彰化 32
# 特別 32
# 解決 32
# 堅持 31
# 候選人 31
# 告訴 31
# 大道 31
# 團隊 31
# 制度 31
# 教育 31
# 創造 30
# 年代 30
# 最大 30
# 繼續 29
# 過程 29
# 服務 29
# 住宅 29
# 原住 29
# 族群 29
# 聲音 28
# 民族 28
# 精神 28
# 立法院 28
# 區域 28
# 保障 28
# 只有 28
# 總統票 28
# 新北市 28
# 晚會 27
# 重新 27
# 基礎 27
# 而是 27
# 立法 27
# 協助 27
# 許多 27
# 浪漫 27
# 迎向 27
# 曾經 27
# 提名 27
# 造勢 27
# 第二 26
# 熱情 26
# 高雄 26
# 機制 26
# 資源 26
# 不過 26
# 這幾年 26
# 人才 26
# 不管 26
# 更是 26
# 將會 26
# 全文 26
# 挑戰 26
# 辛苦 25
# 能力 25
# 權力 25
# 進入 25
# 民意 25
# 時刻 25
# 小英 24
# 當選 24
# 放棄 24
# 而且 24
# 就要 24
# 不要 24
# 成功 24
# 還是 24
# 兩岸 24
# 八年 24
# 方向 24
# 提升 24
# 活動 24
# 走向 24
# 困境 23
# 拒絕 23
# 回家 23
# 真的 23
# 多元 23
# 台電視 23
# 世代 23
# 拍照 23
# 原住民 23
# 網址 23
# 任何 23
# 轉播 23
# 資訊 23
# 委員 22
# 成長 22
# 移民 22
# 雖然 22
# 方式 22
# 變成 22
# 集中 22
# 建設 22
# 專區 22
# 心中 22
# 智慧 22
# 溝通 22
# 失敗 21
# 政黨輪 21
# 替國會 21
# 勞工 21
# 登上 21
# 南投 21
# 臉書 21
# 提醒 21
# 下載 21
# 手板 21
# 打造 21
# 這麼 21
# 兩岸關 21
# 外國民 21
# 僑居國 21
# 你們 21
# 一路 21
# 提供 21
# 彼此 21
# 手中 21
# 升級 21
# 承諾 21
# 決定 21
# 這塊 20
# 能源 20
# 語言 20
# 運動 20
# 加入 20
# 新政府 20
# 選前 20
# 最好 20
# 除了 20
# 權益 20
# 不論 20
# 面對 20
# 堅強 20
# 回來 19
# 發生 19
# 同時 19
# 勇敢 19
# 才能 19
# 一位 19
# 安心 19
# 故鄉 19
# 一年 19
# 可能 19
# 治理 19
# 看見 19
# 孩子 19
# 競選 19
# 理想 19
# 全球 19
# 成立 19
# 堅定 19
# 每個 19
# 能量 19
# 啟動 19
# 主張 18
# 反省 18
# 絕對 18
# 相關 18
# 新國會 18
# 恐嚇 18
# 中華民國 18
# 停滯 18
# 穩定 18
# 召喚 18
# 第一次 18
# 人權 18
# 準備 18
# 目標 18
# 不斷 18
# 不僅 18
# 感動 18
# 感到 18
# 落實 18
# 一點 18
# 並且 18
# 第三 17
# 前進 17
# 做到 17
# 明年 17
# 鼓勵 17
# 各地 17
# 光榮 17
# 十年 17
# 聯合 17
# 結束 17
# 造成 17
# 裡面 17
# 認同 17
# 關鍵 17
# 尤其 17
# 品質 17
# 怎麼 17
# 找回 17
# 賄選 17
# 整個 17
# 態度 16
# 黨團 16
# 大聲公 16
# 驕傲 16
# 加油 16
# 真相 16
# 一件 16
# 美好 16
# 今年 16
# 灣的 16
# 議題 16
# 就業 16
# 再起 16
# 原則 16
# 綠能 16
# 影片 16
# 投入 16
# 展現 16
# 災害 16
# 家庭 16
# 因此 16
# 帶來 16
# 城市 16
# 每一個 16
# 親們 16
# 追求 16
# 街頭 16
# 國家級 16
# 居住 15
# 信心 15
# 世界 15
# 信任 15
# 自由 15
# 弱勢 15
# 共識 15
# 黨產 15
# 包括 15
# 作為 15
# 市場 15
# 客家人 15
# 政見 15
# 困難 15
# 亞洲 15
# 屏東 15
# 維持 15
# 聚落 15
# 訂票 15
# 食品安全 15
# 成績 15
# 忘記 15
# 競爭 15
# 認真 15
# 全世界 14
# 進行 14
# 一月 14
# 充滿 14
# 矽谷 14
# 包容 14
# 事件 14
# 條例 14
# 安全 14
# 面臨 14
# 客語 14
# 安定 14
# 其實 14
# 法案 14
# 了解 14
# 科技 14
# 強化 14
# 一切 14
# 全國區域 14
# 致詞 14
# 全力 14
# 想要 14
# 改善 14
# 處理 14
# 不分區 14
# 出發 14
# 感受 14
# 不到 14
# 發表會 14
# 新竹 14
# 走入 14
# 承擔 13
# 優秀 13
# 獲得 13
# 有人 13
# 粉絲團 13
# 好好 13
# 之間 13
# 其他 13
# 自信 13
# 初衷 13
# 價值 13
# 幫忙 13
# 穩健 13
# 管理 13
# 實現 13
# 回娘家 13
# 政者 13
# 新年 13
# 新北 13
# 討論 13
# 下一代 13
# 任務 13
# 參選人 13
# 說過 13
# 結合 13
# 掃街 13
# 不分 13
# 重建 13
# 重大 13
# 故事 13
# 現場 13
# 甚至 13
# 經過 13
# 帶動 13
# 意義 13
# 證明 13
# 施政 12
# 無論 12
# 那個 12
# 抹黑 12
# 變得 12
# 參與 12
# 二二八 12
# 縣市 12
# 基層 12
# 體系 12
# 深化 12
# 負擔 12
# 走進 12
# 提高 12
# 以來 12
# 和解 12
# 力薦 12
# 買票 12
# 分享 12
# 大選 12
# 艱困 12
# 持續 12
# 最後一里 12
# 食安 12
# 下去 12
# 更加 12
# 對立 12
# 完整 12
# 整合 12
# 保證 12
# 活力 12
# 市民 12
# 經驗 12
# 領導 12
# 取得 11
# 肯定 11
# 正在 11
# 規劃 11
# 攜手 11
# 美樂地 11
# 技術 11
# 關心 11
# 回到 11
# 專家 11
# 邀請 11
# 尊重 11
# 正義的 11
# 不夠 11
# 簡單 11
# 用心 11
# 機械 11
# 等待 11
# 表達 11
# 板橋 11
# 歡迎 11
# 台北市 11
# 心情 11
# 當年 11
# 此刻 11
# 豐富 11
# 透明 11
# 團體 11
# 永續 11
# 結果 11
# 地區 11
# 將來 11
# 利益 11
# 查詢 11
# 決策 11
# 創意 11
# 公民 11
# 擁有 11
# 結構 11
# 道歉 11
# 社區 11
# 當我 11
# 或者 11
# 做出 10
# 一條 10
# 年前 10
# 令人 10
# 各種 10
# 全體 10
# 行銷 10
# 專輯 10
# 藍綠 10
# 夥伴 10
# 一種 10
# 高鐵 10
# 公開 10
# 選戰 10
# 有些 10
# 前輩 10
# 發揮 10
# 記得 10
# 平等 10
# 這種 10
# 一份 10
# 身為 10
# 總部 10
# 角色 10
# 勝利 10
# 議長 10
# 守護 10
# 動力 10
# 更要 10
# 永遠 10
# 一刻 10
# 說明 10
# 哪裡 10
# 模式 10
# 族人 10
# 還會 10
# 黑箱 10
# 中心 10
# 距離 10
# 期盼 10
# 席次 10
# 相挺 10
# 公園 10
# 金門 10
# 現狀 10
# 親愛的 10
# 方法 10
# 迎接 10
# 台北 10
# 其中 10
# 姐妹 10
# 覺得 10
# 經費 10
# 美麗 10
# 下個 10
# 累積 10
# 學生 10
# 中小 10
# 每天 10
# 家人 10
# 相互 10
# 認為 10
# 願意 10
# 值得 10
# 執政黨 10
# 人員 10
# 縣長 10
# 平安 9
# 目前 9
# 一滴 9
# 沉默 9
# 投資 9
# 消失 9
# 張票 9
# 監督 9
# 順利 9
# 那些 9
# 幾個 9
# 幾年 9
# 新時代 9
# 接下 9
# 同仁 9
# 想法 9
# 一代 9
# 還要 9
# 研究 9
# 多年 9
# 生產 9
# 溫暖 9
# 基本 9
# 打敗 9
# 這段 9
# 身分 9
# 接受 9
# 車隊 9
# 記者 9
# 辦法 9
# 醫療 9
# 遇到 9
# 打拼 9
# 國民 9
# 相片 9
# 本土 9
# 受到 9
# 組成 9
# 行動 9
# 舉辦 9
# 歌曲 9
# 權利 9
# 負責 9
# 綠色 9
# 擔任 9
# 增加 9
# 意志 9
# 捍衛 9
# 去年 9
# 制定 9
# 尊嚴 9
# 不再 9
# 針對 9
# 福利 9
# 人物 9
# 快樂 9
# 無法 9
# 階段 9
# 走上 9
# 成熟 9
# 學習 9
# 優質 9
# 爭取 9
# 九二 9
# 不好 9
# 家園 9
# 手上 9
# 日本 9
# 越來 9
# 部落 9
# 從來 9
# 交流 9
# 客庄 9
# 不但 9
# 如何 9
# 總統府 9
# 雲林 9
# 走到 9
# 介紹 9
# 各縣 8
# 日子 8
# 音響 8
# 勇氣 8
# 李幸長 8
# 無能 8
# 生命 8
# 協調 8
# 效率 8
# 分配 8
# 花蓮 8
# 和平 8
# 路上 8
# 最有 8
# 申論 8
# 起點 8
# 一群 8
# 選民 8
# 超過 8
# 建構 8
# 明文 8
# 呼籲 8
# 地震 8
# 即將 8
# 跨過 8
# 關注 8
# 帶著 8
# 台南市 8
# 設施 8
# 再次 8
# 克服 8
# 公共 8
# 機構 8
# 擔心 8
# 支持者 8
# 談判 8
# 修正 8
# 檢討 8
# 選人 8
# 喜歡 8
# 優先 8
# 一句 8
# 領域 8
# 重視 8
# 實踐 8
# 連結 8
# 貿易 8
# 旗子 8
# 打開 8
# 委員會 8
# 基金 8
# 推出 8
# 參加 8
# 調整 8
# 吳宜臻 8
# 民間 8
# 合一 8
# 不應 8
# 留下 8
# 老師 8
# 這股 8
# 人生 8
# 理念 8
# 向前 8
# 利用 8
# 不公 8
# 排名 8
# 需求 8
# 發電 8
# 首都 8
# 找到 8
# 先生 8
# 班次 8
# 強調 8
# 清楚 8
# 十六日 8
# 空間 8
# 開發 8
# 保護 8
# 將是 8
# 里路 8
# 一里 8
# 發聲 8
# 燈會 8
# 新聞稿 7
# 認識 7
# 全面 7
# 平台 7
# 事實 7
# 做好 7
# 台灣頭 7
# 第一步 7
# 創新產業 7
# 參選 7
# 即使 7
# 東南亞 7
# 全部 7
# 主委 7
# 多數 7
# 工程 7
# 也許 7
# 受苦 7
# 第三次 7
# 要求 7
# 購買 7
# 貢獻 7
# 跌倒 7
# 大多 7
# 台鐵 7
# 扮演 7
# 美容 7
# 一些 7
# 身上 7
# 衝突 7
# 友善 7
# 家鄉 7
# 同樣 7
# 特色 7
# 政權 7
# 遊行 7
# 充分 7
# 必要 7
# 農民 7
# 知識 7
# 風險 7
# 民眾 7
# 一場 7
# 正面 7
# 期間 7
# 全台灣 7
# 奮鬥 7
# 農村 7
# 優勢 7
# 盼望 7
# 事業 7
# 禮拜 7
# 走過 7
# 依然 7
# 感覺 7
# 競爭力 7
# 回台灣 7
# 帶領 7
# 不用 7
# 車次 7
# 兩個 7
# 時期 7
# 利潤 7
# 女性 7
# 陪伴 7
# 體質 7
# 設計 7
# 國昌 7
# 原因 7
# 職業 7
# 鄭文燦 7
# 中彰 7
# 普遍 7
# 再過 7
# 如此 7
# 組織 7
# 坐在 7
# 震災 7
# 方案 7
# 以前 7
# 教訓 7
# 青年 7
# 拜訪 7
# 交給 7
# 留給 7
# 動能 7
# 當然 7
# 全力以赴 7
# 援會 7
# 一聲 7
# 核心 7
# 因應 7
# 辦理 7
# 講話 7
# 不安 7
# 來源 7
# 凱達格蘭 7
# 當時 7
# 轉國會 7
# 總統候 7
# 每年 7
# 交接 7
# 院長 7
# 始終 7
# 張宏陸 7
# 最近 7
# 萬人 7
# 叫做 7
# 分散 7
# 人口 7
# 絲團 7
# 救災 7
# 此時 7
# 一段 6
# 物聯網 6
# 認證 6
# 選擇權 6
# 典範 6
# 前面 6
# 正宇 6
# 反核 6
# 沉重 6
# 一流 6
# 一把 6
# 撕裂 6
# 司法 6
# 交通 6
# 作品 6
# 使命 6
# 有著 6
# 真心 6
# 身旁 6
# 培養 6
# 三個 6
# 具有 6
# 降低 6
# 導演 6
# 笑容 6
# 資料 6
# 第四 6
# 體制 6
# 大學 6
# 監票 6
# 是非 6
# 民主自由 6
# 擴大 6
# 做事 6
# 聽到 6
# 鄭運鵬 6
# 一路上 6
# 薪資 6
# 檢驗 6
# 條件 6
# 自主 6
# 大林 6
# 期許 6
# 首先 6
# 安居 6
# 選出 6
# 唯一 6
# 支票 6
# 捐款 6
# 各個 6
# 賴素 6
# 過渡 6
# 昨天 6
# 毅力 6
# 草莓 6
# 失去 6
# 民生 6
# 客運 6
# 太陽花 6
# 生技 6
# 會議 6
# 深入 6
# 十八 6
# 觀光 6
# 之外 6
# 整體 6
# 眼前 6
# 凝聚 6
# 此外 6
# 議會 6
# 所在 6
# 完善 6
# 心裡 6
# 財政 6
# 行列 6
# 投下 6
# 任內 6
# 老先生 6
# 看著 6
# 兩天 6
# 面會 6
# 法規 6
# 恭喜 6
# 表現 6
# 就算 6
# 創作 6
# 不怕 6
# 潛力 6
# 樂業 6
# 所有人 6
# 大門 6
# 逐步 6
# 謙卑 6
# 繁榮 6
# 當中 6
# 信賴 6
# 經常 6
# 可是 6
# 答案 6
# 顧立雄 6
# 兩位 6
# 公司 6
# 快速 6
# 抗議 6
# 經貿 6
# 寒害 6
# 犧牲 6
# 贏回 6
# 開放 6
# 熟悉 6
# 到底 6
# 健康 6
# 缺席 6
# 氫能 6
# 公正 6
# 致力 6
# 各項 6
# 不一樣 6
# 紀念 6
# 遺憾 6
# 食品 6
# 掌握 6
# 期以 6
# 只會 6
# 每一 6
# 反而 6
# 救援 6
# 神聖 6
# 廠商 6
# 幕僚 6
# 多少 6
# 婦女 6
# 報告 6
# 嚴格 6
# 托育 6
# 日政黨票 6
# 漫長 6
# 一部 6
# 願景 6
# 注意 6
# 情況 6
# 承認 6
# 國防產業 6
# 人們 6
# 分黨 5
# 邁向 5
# 勞動 5
# 意見 5
# 勢者 5
# 子弟 5
# 有個 5
# 照體系 5
# 收到 5
# 策略 5
# 作夥 5
# 各業 5
# 經歷 5
# 打出 5
# 失望 5
# 這場 5
# 租屋 5
# 非改 5
# 放心 5
# 年度 5
# 標準 5
# 這句 5
# 農產品 5
# 注重 5
# 需市場 5
# 耕耘 5
# 剛剛 5
# 媒體 5
# 首次 5
# 最新 5
# 電價 5
# 出生 5
# 少數 5
# 艱難 5
# 在乎 5
# 惡鬥 5
# 號旁 5
# 剩下 5
# 這也 5
# 打下 5
# 想到 5
# 林右昌 5
# 陣線 5
# 全國大 5
# 台灣話 5
# 當前 5
# 經營 5
# 應用 5
# 學者 5
# 政局 5
# 對立牌 5
# 台灣贏 5
# 或是 5
# 盡快 5
# 暴力 5
# 根本 5
# 小三通 5
# 嚴肅 5
# 現行 5
# 晚上 5
# 企業界 5
# 當選人 5
# 記憶 5
# 下降 5
# 文彬 5
# 鄭文燦市 5
# 機械產業 5
# 桃園區 5
# 一部分 5
# 這片 5
# 洪宗熠 5
# 障礙 5
# 五十 5
# 資產 5
# 外省 5
# 宛如 5
# 更近 5
# 爭議 5
# 這條 5
# 立院 5
# 上次 5
# 同心 5
# 嘉義縣 5
# 姊妹 5
# 身心 5
# 花媽 5
# 宜蘭 5
# 新能源 5
# 生態 5
# 打氣 5
# 這才 5
# 十六 5
# 重返 5
# 之夜 5
# 作戰 5
# 確保 5
# 出外 5
# 幫助 5
# 展開 5
# 不該 5
# 扛起 5
# 主要 5
# 台中 5
# 薪水 5
# 每次 5
# 珍貴 5
# 攸關 5
# 這幾天 5
# 使用 5
# 程序 5
# 藉由 5
# 老人 5
# 朝野 5
# 國是 5
# 陸委會 5
# 終於 5
# 工業 5
# 林淑芬 5
# 台南人 5
# 生命力 5
# 鄭寶清 5
# 前年 5
# 中正路 5
# 祈求 5
# 不敢 5
# 負起 5
# 桃園場 5
# 好像 5
# 不曾 5
# 留在 5
# 無心 5
# 菊姐 5
# 公室 5
# 疼惜 5
# 當一個 5
# 四個 5
# 思考 5
# 年輕 5
# 互動 5
# 高度 5
# 總是 5
# 災情 5
# 從政 5
# 反應 5
# 預算 5
# 接軌 5
# 破產 5
# 投族 5
# 一代人 5
# 鄭永金 5
# 加強 5
# 都市 5
# 不可 5
# 痛苦 5
# 妹挺 5
# 創業 5
# 正確 5
# 任何人 5
# 高畫質 5
# 黑暗 5
# 鬥爭 5
# 深耕 5
# 一致 5
# 引導 5
# 我會用 5
# 美麗島 5
# 妥善 5
# 老人家 5
# 含淚 5
# 存在 5
# 強韌 5
# 一首 5
# 仍然 5
# 學校 5
# 缺乏 5
# 呂孫綾 5
# 只能 5
# 培慧 5
# 各行 5
# 二月 5
# 命運 5
# 傷害 5
# 分擔 5
# 板凳 5
# 下來 5
# 面前 5
# 走出 5
# 王榮璋 5
# 全民 5
# 開票 5
# 得票率 5
# 特地 5
# 立場 5
# 秀芳 5
# 女孩 5
# 眼中 4
# 在家 4
# 第九 4
# 收回 4
# 兼顧 4
# 星座 4
# 正式 4
# 滿滿 4
# 獨立 4
# 灣人 4
# 大方向 4
# 潛能 4
# 同步 4
# 主人 4
# 法律 4
# 我心 4
# 紀錄片 4
# 對象 4
# 密切 4
# 價格 4
# 花東 4
# 自我 4
# 教授 4
# 產品 4
# 最美 4
# 保留 4
# 精密 4
# 幾乎 4
# 陸續 4
# 一步步 4
# 本黨 4
# 開議 4
# 寫下 4
# 課題 4
# 結起 4
# 太平 4
# 創辦 4
# 一支 4
# 小確幸 4
# 民主化 4
# 餐桌 4
# 發現 4
# 創新研 4
# 打壓 4
# 三件 4
# 難關 4
# 大聲 4
# 給我們 4
# 拜票 4
# 大台 4
# 加工 4
# 比賽 4
# 口號 4
# 離島 4
# 曼麗 4
# 台灣花 4
# 執行 4
# 壓力 4
# 這位 4
# 分裂 4
# 來面 4
# 步伐 4
# 這不 4
# 地點 4
# 上任 4
# 法令 4
# 這件 4
# 一片 4
# 日零時 4
# 我主張 4
# 最深 4
# 遙遠 4
# 年來 4
# 傳統 4
# 高飛 4
# 謝票 4
# 各方 4
# 損失 4
# 選情 4
# 執政縣 4
# 億到 4
# 社會責任 4
# 我將 4
# 扭曲 4
# 中部 4
# 電影 4
# 柯總召 4
# 戰略 4
# 錯誤 4
# 競選團隊 4
# 面向 4
# 像是 4
# 三線 4
# 憲政體制 4
# 讀書 4
# 身份 4
# 目的 4
# 化成 4
# 想想 4
# 心聲 4
# 拚經濟 4
# 南北 4
# 之中 4
# 之下 4
# 南到 4
# 收入 4
# 發光 4
# 履歷 4
# 珍惜 4
# 世凱 4
# 拿下 4
# 的關 4
# 供給 4
# 激烈 4
# 辯論 4
# 帶動產業 4
# 給我 4
# 醫藥 4
# 反對 4
# 傳唱 4
# 同志 4
# 從現 4
# 一席 4
# 出口 4
# 修法 4
# 出去 4
# 影響 4
# 行政院 4
# 出力 4
# 強勢 4
# 世界各地 4
# 蔡適 4
# 出席 4
# 一半 4
# 謝志忠 4
# 深刻 4
# 眼看 4
# 在意 4
# 鄉鎮 4
# 補貼 4
# 研擬 4
# 洛神 4
# 那時 4
# 修改 4
# 被擊 4
# 隨著 4
# 醫護 4
# 多次 4
# 但過 4
# 親手 4
# 三段 4
# 蕭美琴 4
# 拿到 4
# 適合 4
# 常常 4
# 朝方 4
# 嚴峻 4
# 二十 4
# 訂定 4
# 狀況 4
# 市府 4
# 那麼 4
# 淚水 4
# 延續 4
# 陳瑩 4
# 失敗過 4
# 徐景文 4
# 家長 4
# 台灣產業 4
# 存滿 4
# 演講 4
# 訴諸 4
# 蔡培慧 4
# 之前 4
# 兩席 4
# 環保 4
# 財政紀律 4
# 上面 4
# 蔡其昌 4
# 足夠 4
# 通過 4
# 第一站 4
# 祝福 4
# 中國大陸 4
# 中常 4
# 主題 4
# 協商 4
# 修訂 4
# 開啟 4
# 對外 4
# 整理 4
# 毒物 4
# 平衡 4
# 上路 4
# 開創 4
# 障礙者 4
# 積極 4
# 是屬 4
# 智庫 4
# 領導人 4
# 滅亡 4
# 當作 4
# 小孩 4
# 治安 4
# 不滿 4
# 而言 4
# 好多 4
# 感激 4
# 數黨 4
# 回饋 4
# 往前走 4
# 減輕 4
# 加速 4
# 新生 4
# 扶持 4
# 就任 4
# 國人 4
# 張肇良 4
# 秉持 4
# 應變 4
# 育兒 4
# 走來 4
# 理性 4
# 還沒有 4
# 補助 4
# 告一段落 4
# 陷入困境 4
# 政黨法 4
# 志工 4
# 漫見 4
# 洪仲丘 4
# 起責任 4
# 共享 4
# 蘇治芬 4
# 台東 4
# 有用 4
# 不僅僅 4
# 贏得 4
# 倒數 4
# 容易 4
# 具體 4
# 藉口 4
# 最高 4
# 情感 4
# 公約 4
# 瞭解 4
# 杜文卿 4
# 堅實 4
# 靠山 4
# 海外 4
# 議員 4
# 熠席 4
# 影像 4
# 林靜儀 4
# 立即 4
# 發產業 4
# 立刻 4
# 短期 4
# 成果 4
# 媽媽 4
# 審查 4
# 這首 4
# 兩次 4
# 原本 4
# 嚴故 4
# 音樂 4
# 小英動 4
# 領台灣 4
# 還在 4
# 小組 4
# 休閒 4
# 中山南路 4
# 職場 4
# 電子 4
# 滄江 4
# 威權 4
# 有史 3
# 多麼 3
# 高興 3
# 星期五 3
# 另有 3
# 佳濱 3
# 這一屆 3
# 加上 3
# 各級 3
# 基地 3
# 減到 3
# 出新 3
# 舞台 3
# 龐大 3
# 有利於 3
# 挑釁 3
# 用小豬 3
# 日常 3
# 翻轉 3
# 運作 3
# 起身 3
# 一哩路 3
# 傳承 3
# 體三 3
# 只為 3
# 三項 3
# 主任 3
# 夜市 3
# 黨員 3
# 深深 3
# 一首歌 3
# 要給 3
# 邀集 3
# 台灣隊 3
# 法庭 3
# 主持 3
# 技職 3
# 三大 3
# 西路 3
# 致政粉 3
# 勞委會 3
# 偉哲 3
# 事宜 3
# 休息 3
# 雄有 3
# 崇德 3
# 現階段 3
# 告別 3
# 上升 3
# 經有 3
# 美琴 3
# 邱志偉 3
# 經是 3
# 有心 3
# 同意 3
# 直接 3
# 焦慮 3
# 平地 3
# 擔憂 3
# 當總統 3
# 再生能源 3
# 理解 3
# 一枚 3
# 中華 3
# 發熱 3
# 教會 3
# 考驗 3
# 南島路 3
# 生技產業 3
# 何欣純 3
# 說出 3
# 指定 3
# 嚴重 3
# 明白 3
# 產值 3
# 要當 3
# 日新國會 3
# 不願意 3
# 一旦 3
# 一早 3
# 負責任 3
# 二十年 3
# 全國小豬 3
# 均衡 3
# 比較 3
# 當我們 3
# 事務廣場 3
# 低迷 3
# 小鎮 3
# 邱議瑩 3
# 嘉義市 3
# 設備 3
# 金山 3
# 記取 3
# 拖延 3
# 出現 3
# 最後一哩路 3
# 傾聽 3
# 北屯 3
# 申請 3
# 參觀 3
# 大埔 3
# 管理系 3
# 側門 3
# 含血 3
# 參訪 3
# 變化 3
# 安慰 3
# 唐山 3
# 哭泣 3
# 法人 3
# 這份 3
# 誠信 3
# 落地生根 3
# 改革方案 3
# 高高 3
# 遵循 3
# 募集 3
# 同理 3
# 台電 3
# 遇見 3
# 倒退 3
# 然而 3
# 效果 3
# 一大步 3
# 能為 3
# 低薪 3
# 集會 3
# 對面 3
# 參考 3
# 實力 3
# 母語 3
# 號對面 3
# 黑金 3
# 高齡 3
# 奔波 3
# 迫切需要 3
# 定位 3
# 一生 3
# 抱怨 3
# 加倍 3
# 為榮 3
# 嚴肅面 3
# 圖片 3
# 善良 3
# 下雨 3
# 包機 3
# 部分 3
# 態系 3
# 萬難 3
# 眼淚 3
# 百年 3
# 一下 3
# 推廣 3
# 在後面 3
# 特質 3
# 保存 3
# 員林市 3
# 血液 3
# 這兩個 3
# 大會 3
# 首度 3
# 未能 3
# 天氣 3
# 美女 3
# 這群 3
# 回應 3
# 福利待遇 3
# 台中場 3
# 兌現 3
# 重鎮 3
# 棒球 3
# 腳步 3
# 美國 3
# 通知 3
# 文告 3
# 瑞隆 3
# 許智傑 3
# 高雄人 3
# 出任 3
# 產業界 3
# 最強 3
# 作用 3
# 杜絕 3
# 衰敗 3
# 影視 3
# 南台 3
# 生物 3
# 之一 3
# 突破 3
# 陷入 3
# 張聘書 3
# 追討 3
# 微笑 3
# 大湖 3
# 幾天 3
# 南向 3
# 立言 3
# 空地 3
# 幾歲 3
# 廖萬堅 3
# 打破 3
# 豬公 3
# 奠定 3
# 保障法 3
# 天空 3
# 苗栗人 3
# 那樣 3
# 表演 3
# 官方 3
# 有所 3
# 渴望 3
# 有意 3
# 悲情 3
# 一套 3
# 許諾 3
# 莊瑞雄 3
# 身影 3
# 義的 3
# 換骨 3
# 一度 3
# 真是 3
# 規模 3
# 交到 3
# 選上 3
# 停止 3
# 行政部 3
# 講出 3
# 推動區域 3
# 登真 3
# 庄產業 3
# 呼喚 3
# 戰力 3
# 衝擊 3
# 不起 3
# 劉世芳 3
# 林俊憲 3
# 並肩 3
# 很難 3
# 踏出 3
# 農損 3
# 經因 3
# 一再 3
# 律師 3
# 怎麼樣 3
# 歌詞 3
# 陣容 3
# 借給 3
# 母親 3
# 激戰 3
# 電網 3
# 揮揮手 3
# 忍不住 3
# 平時 3
# 直到 3
# 運用 3
# 一同 3
# 施工 3
# 一向 3
# 好不好 3
# 政績 3
# 帶頭 3
# 著小豬 3
# 會動盪 3
# 系統 3
# 人選 3
# 雙手 3
# 中央政府 3
# 包袱 3
# 當地 3
# 時時 3
# 第十四 3
# 場電視 3
# 死刑 3
# 拿出 3
# 份子 3
# 這一點 3
# 莒光 3
# 相當 3
# 特殊 3
# 格外 3
# 現況 3
# 婦權 3
# 史上 3
# 有限 3
# 大聯盟 3
# 得以 3
# 訊息 3
# 避免 3
# 太陽 3
# 海洋 3
# 完全 3
# 半導 3
# 計劃 3
# 挺身而出 3
# 合力 3
# 交口 3
# 滴滴 3
# 遠遠 3
# 谷底 3
# 國書 3
# 拉票 3
# 最後的 3
# 壯大 3
# 產銷 3
# 分別 3
# 向前走 3
# 道路 3
# 全力支持 3
# 換掉 3
# 調查 3
# 成就 3
# 查驗 3
# 時俱進 3
# 魔戒 3
# 財源 3
# 人情 3
# 商機 3
# 龍燈 3
# 營事業 3
# 通車 3
# 女生 3
# 橋梁 3
# 致政 3
# 還給 3
# 旅遊 3
# 仔細 3
# 經濟要 3
# 生計 3
# 原來 3
# 車票 3
# 逐漸 3
# 在野 3
# 黑心 3
# 期照 3
# 藝術 3
# 引擎 3
# 交付 3
# 黨營 3
# 天麟 3
# 公務員 3
# 不想 3
# 虎尾 3
# 公報 3
# 場合 3
# 以外 3
# 代子 3
# 西區 3
# 不必 3
# 付出 3
# 節哀 3
# 食安五環 3
# 萬戶 3
# 傷痕 3
# 灣之子 3
# 實際 3
# 振興 3
# 更會 3
# 管道 3
# 中國 3
# 下一個 3
# 嘉義 3
# 當你 3
# 這三個 3
# 家己 3
# 四席 3
# 消費 3
# 帶給 3
# 更新 3
# 鎮光 3
# 功能 3
# 李昆澤 3
# 金錢 3
# 資訊及 3
# 孤單 3
# 慚愧 3
# 勿忘 3
# 本來 3
# 改作 3
# 蔡易餘 3
# 國際級 3
# 聽過 3
# 做起 3
# 表示 3
# 六個 3
# 一新 3
# 辜老 3
# 作者 3
# 委員粉 3
# 王定宇 3
# 整碗 3
# 我承諾 3
# 對此 3
# 開會 3
# 這一哩路 3
# 山脈 3
# 禁止 3
# 人事 3
# 觀光產業 3
# 只靠 3
# 空頭 3
# 徵收 3
# 待遇 3
# 中海 3
# 中洲 3
# 張國鑫 3
# 歷程 3
# 以此 3
# 洪慈庸 3
# 生產力 3
# 有責任 3
# 當選證 3
# 脫胎 3
# 升格 3
# 公益 3
# 葉宜津 3
# 家屬 3
# 達成 3
# 做律師 3
# 補償 3
# 煥然 3
# 小時 3
# 各類 3
# 下台 3
# 電業法 3
# 敬意 3
# 紀律 3
# 永不 3
# 促進 3
# 意外 3
# 保險 3
# 無數 3
# 栽贓 3
# 南部 3
# 出身 3
# 多點 3
# 出路 3
# 優良 3
# 女士 3
# 管碧玲 3
# 敗選 3
# 健全 3
# 徹底 3
# 接著 3
# 一號 3
# 身處 3
# 方面 3
# 直航 3
# 合理 3
# 跨出 3
# 不容 3
# 場停 3
# 受害者 3
# 擺脫 3
# 左楠 3
# 很少 3
# 或許 3
# 桃竹苗 3
# 引起 3
# 蘇震清 3
# 措施 3
# 一顆 3
# 堅守 3
# 蔡煌瑯 3
# 攝影 3
# 脫離 3
# 鐵票 3
# 住民 3
# 雲林場 3
# 記錄 3
# 車場 3
# 適應 3
# 污染 3
# 處境 3
# 中立 3
# 道理 3
# 性別 3
# 落差 3
# 很大 3
# 從事 3
# 歐吉桑 3
# 單位 3
# 傳達 3
# 學歷 3
# 予以 3
# 福祉 3
# 逆風 3
# 不義的 3
# 整年 3
# 交換 3
# 第二次 3
# 現出 3
# 處理過 3
# 簽唱會 3
# 公眾 3
# 應鏈 3
# 致上 3
# 二段 3
# 誕生 3
# 名表 3
# 燃起 3
# 匯集 3
# 板橋區 3
# 共商 3
# 公然 3
# 搶救 3
# 行政 3
# 綠能業者 3
# 能否 3
# 統聯 3
# 翻盤 3
# 藝文特區 3
# 國光 3
# 含恨 3
# 處分 3
# 中為 3
# 遊子 3
# 紙條 3
# 預定 3
# 林岱 3
# 沿著 2
# 事務 2
# 行動來 2
# 質詢 2
# 三年 2
# 結合產 2
# 過得 2
# 過年 2
# 遭遇 2
# 集結 2
# 對話 2
# 三弓 2
# 習會 2
# 趁著 2
# 一根 2
# 東楓 2
# 配音 2
# 沈重 2
# 正義在 2
# 蠢羊 2
# 爸爸 2
# 二十五 2
# 公辦 2
# 歷史性 2
# 市政府 2
# 檔案 2
# 之三 2
# 貸款 2
# 緊緊 2
# 淡水 2
# 沿路上 2
# 敬請 2
# 執政時 2
# 節能 2
# 生存 2
# 桌上 2
# 逮捕 2
# 問政品 2
# 作家 2
# 濱田 2
# 銜接 2
# 超越 2
# 老舊 2
# 公視 2
# 過難關 2
# 這將 2
# 涉入 2
# 台語 2
# 天佑 2
# 這一塊 2
# 求同 2
# 阿才 2
# 現有 2
# 戒除 2
# 廣場 2
# 難者 2
# 北京 2
# 電視劇 2
# 這張 2
# 思辨 2
# 動態 2
# 農場 2
# 子子 2
# 分類 2
# 嘉義鄉親 2
# 災難 2
# 解釋 2
# 悲哀 2
# 神明 2
# 有力 2
# 鐵路 2
# 典禮 2
# 心意 2
# 三天 2
# 第四天 2
# 通報 2
# 動漫 2
# 最終 2
# 一扇 2
# 小學生 2
# 結識 2
# 推進 2
# 投身 2
# 父母 2
# 結論 2
# 最後一場 2
# 最後階段 2
# 沒辦法 2
# 農地 2
# 絕不 2
# 中斷 2
# 先進 2
# 阻礙 2
# 幫台灣 2
# 改頭 2
# 打招呼 2
# 信念 2
# 非核 2
# 我剛 2
# 詳細 2
# 有什麼 2
# 幾位 2
# 我則 2
# 六大 2
# 上午 2
# 先鋒 2
# 請桃園 2
# 平價 2
# 被判 2
# 懈怠 2
# 變來 2
# 韓國 2
# 隊伍 2
# 音產業 2
# 學運 2
# 敏感 2
# 一時 2
# 外交 2
# 光電 2
# 賴清德 2
# 時代裡 1
# 其他人 1
# 共勉 1
# 天府 1
# 能達 1
# 付給 1
# 深遠 1
# 九大 1
# 純樸 1
# 執行長 1
# 大安溪 1
# 英九時代 1
# 安詳 1
# 輔導 1
# 霧島 1
# 外交部 1
# 拒馬 1
# 擬定 1
# 一陣 1
# 盛宴 1
# 印刻 1
# 北投 1
# 來給 1
# 還很年 1
# 分成 1
# 貿談判 1
# 這五個 1
# 光明 1
# 九年 1
# 光是 1
# 專責小組 1
# 地用 1
# 沈潛 1
# 還做 1
# 珍珠奶茶 1
# 花錢 1
# 喝杯 1
# 購民間 1
# 中高齡 1
# 最誠實 1
# 鎮的 1
# 第五天 1
# 勇敢的人 1
# 摩擦 1
# 秘書長 1
# 肥料 1
# 換句 1
# 確定 1
# 對美琴 1
# 召開 1
# 近幾年 1
# 徒步 1
# 遲來 1
# 米蘭小鎮 1
# 撥出 1
# 連我們 1
# 大年初一 1
# 一面 1
# 尾牙 1
# 喊口號 1
# 預測性 1
# 獄方 1
# 何況 1
# 這歷史 1
# 我太過 1
# 必定 1
# 農民站 1
# 唯二 1
# 及產業 1
# 女總統 1
# 呂孫綾贏 1
# 姚文智 1
# 診斷 1
# 走台 1
# 海內外 1
# 孫女 1
# 貸關 1
# 國力 1
# 得民心 1
# 四種 1
# 國共 1
# 有無數 1
# 會作 1
# 引以 1
# 對症 1
# 閒話 1
# 引人 1
# 要連 1
# 奮力 1
# 怎能 1
# 種子 1
# 反過 1
# 它永遠 1
# 分輸贏 1
# 第一名 1
# 安裝 1
# 要蓋 1
# 我們絕 1
# 不得 1
# 及遊民 1
# 洽公辦 1
# 切呼籲 1
# 手黨 1
# 先期 1
# 啟動產業 1
# 盡身 1
# 先有 1
# 封為 1
# 船運票價 1
# 法規能 1
# 大遊行 1
# 循序 1
# 航權 1
# 國家終 1
# 我會擔 1
# 統與 1
# 順利換 1
# 任期 1
# 奔跑 1
# 輕心 1
# 影展 1
# 腥風 1
# 縮短學用 1
# 拋售 1
# 選後都 1
# 漁村 1
# 但國民黨 1
# 必然 1
# 轉現 1
# 金永續 1
# 造型 1
# 急救 1
# 辦海報 1
# 投注 1
# 認知 1
# 更積極 1
# 高級 1
# 漸進 1
# 消極 1
# 隔夜 1
# 心在 1
# 直選 1
# 前導型 1
# 曾為 1
# 給國人 1
# 孫子 1
# 含愛 1
# 語文 1
# 接過 1
# 將沿 1
# 儲能 1

# %% [markdown]
# ## 蘋果日報-即時新聞抓取

# %%
import requests 
import re
from bs4 import BeautifulSoup as bs 
res = requests.get('http://www.appledaily.com.tw/realtimenews/section/new/')
soup = bs(res.text)
news = soup.select('.rtddt a')
for new in news:
    #法一 直接印出來
    #print new.select('h1')[0].text
    #法二，利用group 把資料先進行分組(group)
    m = re.match('(?P<title>.*)\((?P<popularity>\d+)\)',new.select('h1')[0].text)   # \( 是跳脫字元的概念
    print m.group('title'),m.group('popularity')
# Out:
# 單親家庭長大被嫌不正常　網友神解關鍵在此 0
# 隆達2015年EPS 0.45元 0
# 駕BMW試乘車撞死人　業務員鞠躬道歉 0
# 歷史次慘　高雄2月申報開工僅20戶 56
# 2年新低　日月光2月營收僅176.4億　17
# 【央廣RTI】每天200萬桶  伊朗石油... 56
# 【影片】美國前第一夫人　南茜雷根94歲逝... 45507
# 持白色恐怖文件涉贓物罪？　士檢下午分案 2868
# 【更新】憲兵濫搜爭議　北檢傳訊5官兵全請... 39706
# 【更新】毛毛der　何潤東戲裡戲外傷同手 851
# 【台灣英文新聞】自己的故事自己說！新二代... 14
# 驚傳首宗Mac中毒！　還要付贖金 77
# 全球最大飛行器將試飛　足球場長6輛巴士高 483
# 「隱藏選手」不是人　亂入單車賽讓網友笑噴 530
# 【壹週刊】看Line購物享7天解約期嗎？ 0
# 自己的山林自己救　銅門部落舉報山老鼠 3045
# 柯P為憲兵濫搜緩頰　她批柯沒搞清軍隊角色 854
# 【央廣RTI】伊拉克自殺攻擊  上百人死... 75
# 【更新】騙過驗鈔機　假美鈔領走6600萬... 58801
# 郵局員工肖想同事妻　在電梯裡就硬來 2097
# 驚險！購物車衝落電扶梯　母女被撞飛 776
# 【哎呀】大好天氣的　牠怎麼抖成這樣 421
# 壯男搶加油站　飆逃犁田腫成豬頭 1727
# 中國農業部長：到國外搶奶粉是恥辱 367
# 【央廣RTI】茲卡病毒可能引發胎兒更多問... 177
# 閃爆眼的手機外殼　 5千才能得手 629
# 【更新】唐安琪焚身女伴身分曝光　做筆錄沒... 118293
# 【更新】連13黑　2月出口年減11.8% 14352
# 【法廣RFI】銅鑼灣書店再一人被銷案 特... 52
# 驚見噁男遛老鳥　女怒：下次看到剪掉 7047
# C:\Users\BIG DATA\Anaconda2\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
#把上面的資料做成 Data frame 進行整理
import requests 
import re
from bs4 import BeautifulSoup as bs 
import pandas as pd
res = requests.get('http://www.appledaily.com.tw/realtimenews/section/new/')
soup = bs(res.text)
news = soup.select('.rtddt a')
news_list = []
for new in news:
    m = re.match('(?P<title>.*)\((?P<popularity>\d+)\)',new.select('h1')[0].text) 
    category = new.select('h2')[0].text  #把新聞類型存起來
    news_list.append({                # {} 是為了能多行或容納更多的() 'name'可直接給定名稱
            'title':m.group('title'),\
            'popularity':int(m.group('popularity')),\
            'category':category
        })

# %%
df = pd.DataFrame(news_list)
df.sort(['popularity'],ascending=False).head(50)  #ascending=False 由大排到小
# Out:
# C:\Users\BIG DATA\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#    category  popularity                    title
# 29       社會       61807  【更新】騙過驗鈔機　假美鈔領走6600萬...
# 17       國際       45988  【影片】美國前第一夫人　南茜雷根94歲逝...
# 19       社會       42012  【更新】憲兵濫搜爭議　北檢傳訊5官兵全請...
# 7        財經       16545     【更新】連13黑　2月出口年減11.8%
# 6        國際       11929  ​【更新】澳洲槍擊案2死2傷　槍手與警對...
# 26       社會        3363       自己的山林自己救　銅門部落舉報山老鼠
# 18       社會        3261      持白色恐怖文件涉贓物罪？　士檢下午分案
# 27       生活        2958     柯P為憲兵濫搜緩頰　她批柯沒搞清軍隊角色
# 13       社會        2792       駕BMW試乘車撞死人　業務員鞠躬道歉
# 24       動物        1550     「隱藏選手」不是人　亂入單車賽讓網友笑噴
# 20       娛樂        1297     【更新】毛毛der　何潤東戲裡戲外傷同手
# 23       國際        1195     全球最大飛行器將試飛　足球場長6輛巴士高
# 11       生活        1140     單親家庭長大被嫌不正常　網友神解關鍵在此
# 9        財經        1012     【挑戰8700失敗】仍收漲16點　連7紅
# 14       地產         892        歷史次慘　高雄2月申報開工僅20戶
# 22       財經         772         驚傳首宗Mac中毒！　還要付贖金
# 16       國際         592  【央廣RTI】每天200萬桶  伊朗石油...
# 10       生活         245       【壹週刊】漏水問題沒釐清　業者先卸責
# 15       財經         225     2年新低　日月光2月營收僅176.4億
# 28       國際         218  【央廣RTI】伊拉克自殺攻擊  上百人死...
# 12       財經         136      隆達去年每股賺0.45元　上月營收微降
# 25       生活          89     【壹週刊】看Line購物享7天解約期嗎？
# 21       生活          73  【台灣英文新聞】自己的故事自己說！新二代...
# 8        政治          61      【憲兵濫搜】憲兵指揮官：魏姓民眾是嫌犯
# 5        國際          16       澳洲工廠氯氣洩漏緊急疏散　43人送醫
# 1        3C           0       【GAME啥】與正妹聊天　女神就降臨
# 4        國際           0  【央廣RTI】科學家偏心  「醜陋」動物...
# 3        娛樂           0  SNH48祈福公演進帳69萬　全捐唐安琪...
# 2        時尚           0          小鎂優雅穿香奈兒　和潮媽比衣Q
# 0        社會           0        砂石車閃車撞山壁　2水泥涵管掉路面

# %% [markdown]
# ## 統整程式碼-如何把資料匯入資料庫

# %% [markdown]
# ### 步驟0 引用套件

# %%
from bs4 import BeautifulSoup 
from datetime import datetime 
import os, sys, re

# %% [markdown]
# ### 步驟1 建立資料抽出函式

# %%
#只需要檔案裡面表格的部分
def get_response_element (file_name):
    f = open(file_name,'r')
    response_text = f.read()
    f.close()
    soup = BeautifulSoup(response_text)
    tender_table = soup.select('.table_block.tender_table')[0]
    tr = tender_table.select('tr')
    return tr

# %%
#試看看抓不抓得到
print get_response_element('C:/Users/BIG DATA/Desktop/python_homework2/51760773_104150330477.text')
# Out:
# [<tr>\n<td align="center" colspan="4" style="border:1px solid #FFFFFF;">\n<center>\n<h1>\n       \u66f4\u6b63\u6c7a\u6a19\u516c\u544a\n      </h1>\n</center>\n<div align="center" id="printAwardDate" style="display:block">\n<h3>\n       \u516c\u544a\u65e5:105/02/24\n      </h3>\n</div>\n<div class="remind_msg">\n</div>\n</td>\n</tr>, <tr class="award_table_tr_1" id="noneDisWord">\n<td align="left" class="T12" colspan="4">\n     \u8a3b\uff1a\n     <font color="red">\n<strong>\n       \u25ce\n      </strong>\n</font>\n     \u7d05\u8272\u5b57\u9ad4\u8868\u793a\u6b64\u6b21\u66f4\u6b63\u516c\u544a\u8207\u524d\u6b21\u4e4b\u5dee\u7570\uff0c\u524d\u6b21\u516c\u544a\u5167\u5bb9\u65bc\u6ed1\u9f20\u79fb\u81f3\u6587\u5b57\u4e0a\u65b9\u6642\u81ea\u52d5\u986f\u793a\n    </td>\n</tr>, <tr class="award_table_tr_1">\n<td align="center" bgcolor="#89C0C7" class="style1" rowspan="8" valign="middle" width="38">\n<span class="newstop">\n      \u6a5f\n      <br/>\n      \u95dc\n      <br/>\n      \u8cc7\n      <br/>\n      \u6599\n     </span>\n</td>\n</tr>, <tr class="award_table_tr_1">\n<th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">\n     \u6a5f\u95dc\u4ee3\u78bc\n    </th>\n<td bgcolor="#EFF1F1" class="newstop" height="25">\n     3.76.54\n    </td>\n</tr>, <tr class="award_table_tr_1">\n<th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">\n     \u6a5f\u95dc\u540d\u7a31\n    </th>\n<td bgcolor="#EFF1F1" class="newstop" height="25">\n     \u81fa\u6771\u7e23\u653f\u5e9c\n    </td>\n</tr>, <tr class="award_table_tr_1">\n<th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">\n     \u55ae\u4f4d\u540d\u7a31\n    </th>\n<td bgcolor="#EFF1F1" class="newstop" height="25">\n     \u81fa\u6771\u7e23\u653f\u5e9c\n    </td>\n</tr>, <tr class="award_table_tr_1">\n<th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">\n     \u6a5f\u95dc\u5730\u5740\n    </th>\n<td bgcolor="#EFF1F1" class="newstop" height="25">\n     950\u81fa\u6771\u7e23\u81fa\u6771\u5e02\u4e2d\u5c71\u8def276\u865f\n    </td>\n</tr>, <tr class="award_table_tr_1">\n<th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">\n     \u806f\u7d61\u4eba\n    </th>\n<td bgcolor="#EFF1F1" class="newstop" height="25">\n     \u6f01\u696d\u79d1\uff0c\u627f\u8fa6\u4eba\uff1a\u9673\u6587\u6cf0\u5148\u751f\n    </td>\n</tr>, <tr class="award_table_tr_1">\n<th align="left" bgcolor="#DAEBED" class="T11b" valign="middle" width="200">\n     \u806f\u7d61\u96fb\u8a71\n    </th>\n<td bgcolor="#EFF1F1" class="newstop" height="25">\n     (089)343209\n    </td>\n</tr>, <tr class="award_table_tr_1">\n<th align="left" bgcolor="#DAEBED" class="T11b" style="height: 25px" valign="middle" width="200">\n     \u50b3\u771f\u865f\u78bc\n    </th>\n<td bgcolor="#EFF1F1" class="newstop" height="25">\n     (089)343209\n    </td>\n</tr>, <tr class="award_table_tr_2">\n<td align="center" bgcolor="#FCD847" class="form_head" rowspan="30 " valign="middle" width="38">\n<span class="newstop">\n      \u5df2\n      <br/>\n      \u516c\n      <br/>\n      \u544a\n      <br/>\n      \u8cc7\n      <br/>\n      \u6599\n     </span>\n</td>\n</tr>, <tr class="award_table_tr_2">\n<th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">\n     \u6a19\u6848\u6848\u865f\n    </th>\n<td bgcolor="#EFF1F1" class="newstop">\n     104150330477\n    </td>\n</tr>, <tr class="award_table_tr_2">\n<th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">\n     \u62db\u6a19\u65b9\u5f0f\n    </th>\n<td bgcolor="#EFF1F1" class="newstop">\n     \u9650\u5236\u6027\u62db\u6a19(\u7d93\u516c\u958b\u8a55\u9078\u6216\u516c\u958b\u5fb5\u6c42)\n     <div class="remind_msg">\n</div>\n</td>\n</tr>, <tr class="award_table_tr_2">\n<th align="left" bgcolor="#FFFF99" class="T11b" valign="middle" width="200">\n     \u6c7a\u6a19\u65b9\u5f0f\n    </th>\n<td bgcolor="#EFF1F1" class="newstop">\n     \u6e96\u7528\u6700\u6709\u5229\u6a1 ...

# %% [markdown]
# ### 步驟2 建立時間轉換函式

# %%
#要把表格內的時間的部分，轉換成時間的格式
def date_conversion(element):
        m = re.match("(\d+/\d+/\d+)",element)
        if m is not None:
                t = m.group(1).split('/', 1)
                if t[0] != '':
                        return datetime.strptime(str(int(t[0]) + 1911) + "/" + (''.join(t[1:]).split()[0] ), "%Y/%m/%d")
        else:
                return None

# %%
date_conversion('102/02/03')
# Out:
# datetime.datetime(2013, 2, 3, 0, 0)

# %% [markdown]
# ### 步驟3 建立金額轉換函式

# %%
def money_conversion(element):
    m = re.match("\$?([0-9,]+)", "".join(element.split()))
    return int(''.join(m.group(0).split(',')))

# %%
money_conversion('123,111元')
# Out:
# 123111

# %% [markdown]
# ### 步驟4 建立移除空白函式

# %%
def remove_space(element): 
    return "".join(element.split())

# %% [markdown]
# ### 步驟5 建立轉換字典

# %%
name_map = {"機關代碼":"entity_code", "機關名稱":"procuring_entity","標案案號":"job_number","招標方式":"procurement_type",\
    "決標方式":"tender_awarding_type","標案名稱":"subject_of_procurement", "決標資料類別":"attr_of_tender_awarding", \
    "標的分類":"attr_of_procurement", "預算金額":"budget_value", "開標時間":"opening_date","決標公告日期":"tender_awarding_announce_date",\
    "歸屬計畫類別":"project_type","總決標金額":"total_tender_awarding_value","底價金額":"floor_price_value","決標日期":"tender_awarding_date", "pkAtmMain":"pkAtmMain"}

#也可把上面寫的函數存進字典裡面
tender_awards_map = {"機關代碼":remove_space, "機關名稱":remove_space, "標案案號":remove_space, \
    "招標方式":remove_space,"決標方式":remove_space,"標案名稱":remove_space, "決標資料類別":remove_space, \
    "標的分類":remove_space, "預算金額":money_conversion, "開標時間":date_conversion,"歸屬計畫類別":remove_space, \
    "總決標金額":money_conversion,"底價金額":money_conversion,"決標日期":date_conversion, "決標公告日期":date_conversion}

# %% [markdown]
# ### 步驟6 建立整理機關、已公告、決標資料之函式

# %%
def get_award_info_dic(element):
    returned_dic = {}
    for row in element:
        th = row.select('th')
        if len(th) > 0:
            th_name = th[0].text.encode('utf-8').strip()
            if (th_name in  tender_awards_map):
                returned_dic[name_map[th_name]]   =   tender_awards_map[th_name](row.select('td')[0].text.strip())
    return returned_dic

# %%
ele = get_response_element('C:/Users/BIG DATA/Desktop/python_homework2/51760773_104150330477.text')
get_award_info_dic(ele)
# Out:
# {'attr_of_procurement': u'<\u52de\u52d9\u985e>8673\u7d9c\u5408\u5de5\u7a0b\u670d\u52d9',
#  'attr_of_tender_awarding': u'\u6c7a\u6a19\u516c\u544a',
#  'budget_value': 6809524,
#  'entity_code': u'3.76.54',
#  'floor_price_value': 6182331,
#  'job_number': u'104150330477',
#  'opening_date': datetime.datetime(2015, 12, 11, 0, 0),
#  'procurement_type': u'\u9650\u5236\u6027\u62db\u6a19(\u7d93\u516c\u958b\u8a55\u9078\u6216\u516c\u958b\u5fb5\u6c42)',
#  'procuring_entity': u'\u81fa\u6771\u7e23\u653f\u5e9c',
#  'project_type': u'\u975e\u5c6c\u611b\u53f0\u5341\u4e8c\u9805\u8a08\u756b',
#  'subject_of_procurement': u'\u5bcc\u5ca1\u6f01\u6e2f\u707d\u5f8c\u5fa9\u5efa\u5de5\u7a0b\u8a2d\u8a08\u53ca\u76e3\u9020\u5de5\u4f5c',
#  'tender_awarding_announce_date': datetime.datetime(2016, 2, 24, 0, 0),
#  'tender_awarding_date': datetime.datetime(2015, 12, 30, 0, 0),
#  'tender_awarding_type': u'\u6e96\u7528\u6700\u6709\u5229\u6a19',
#  'total_tender_awarding_value': 6182331}

# %% [markdown]
# ### 步驟7 瀏覽整理過的資料

# %%
element = get_response_element('C:/Users/BIG DATA/Desktop/python_homework2/51760773_104150330477.text')
dic = get_award_info_dic(element)
for ele in dic:
    print ele, dic[ele]
# Out:
# opening_date 2015-12-11 00:00:00
# total_tender_awarding_value 6182331
# tender_awarding_date 2015-12-30 00:00:00
# entity_code 3.76.54
# procurement_type 限制性招標(經公開評選或公開徵求)
# procuring_entity 臺東縣政府
# attr_of_procurement <勞務類>8673綜合工程服務
# tender_awarding_announce_date 2016-02-24 00:00:00
# subject_of_procurement 富岡漁港災後復建工程設計及監造工作
# project_type 非屬愛台十二項計畫
# attr_of_tender_awarding 決標公告
# budget_value 6809524
# floor_price_value 6182331
# job_number 104150330477
# tender_awarding_type 準用最有利標

# %% [markdown]
# ## 資料儲存與分析

# %% [markdown]
# ## 下載Sqlite Manager:
# 1. 圖型化的資料庫套件，要在firefox才能用
# 2. 開啟後→Database→Connect Database→選擇你設定的xxxxx.sqlite資料庫

# %%
import sqlite3
db = sqlite3.connect('test.sqlite')  #會在所處位置之下產生一個test.sqlite資料庫連線檔案
cur = db.cursor()    #cursor()是一個游標的概念，例如：指向資料庫的第一列
#建立table及欄位名稱
cur.execute('''CREATE TABLE IF NOT EXISTS Tender_awards(
                id INTEGER PRIMARY KEY,
                pkAtmMain TEXT,
                procuring_entity TEXT,
                entity_code TEXT,
                attr_of_procurement TEXT,
                opening_date DATETIME,
                procurement_type TEXT,
                tender_awarding_type TEXT,
                project_type TEXT,
                subject_of_procurement TEXT,
                job_number TEXT,
                budget_value BIGINTEGER,
                attr_of_tender_awarding TEXT,
                floor_price_value BIGINTEGER,
                tender_awarding_announce_date DATETIME,
                tender_awarding_date DATETIME,
                total_tender_awarding_value BIGINTEGER
                )''')
db.close()   #要記得關閉資料庫

# %%
element = get_response_element('C:/Users/BIG DATA/Desktop/python_homework2/51760773_104150330477.text')
dic = get_award_info_dic(element)

# insert into Tender_awards (c1, c2, c3...) values(v1, v2, v3)
# insert into Tender_awards (c1, c2, c3...) values(?,?,?)

sql = 'insert into Tender_awards ({}) values({})'
columns =  ', '.join(dic.keys())
print len(dic)
print len(dic) * '?'
print ','.join(len(dic) * '?')
placeholders = ','.join(len(dic) * '?')

print sql.format(columns, placeholders)
print dic.values()

#cur.execute(sql,award_info_dic.values())
#columns =  ', '.join(dic.keys())
#for ele in dic:
#    print ele, dic[ele]
# Out:
# 15
# ???????????????
# ?,?,?,?,?,?,?,?,?,?,?,?,?,?,?
# insert into Tender_awards (opening_date, total_tender_awarding_value, tender_awarding_date, entity_code, procurement_type, procuring_entity, attr_of_procurement, tender_awarding_announce_date, subject_of_procurement, project_type, attr_of_tender_awarding, budget_value, floor_price_value, job_number, tender_awarding_type) values(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)
# [datetime.datetime(2015, 12, 11, 0, 0), 6182331, datetime.datetime(2015, 12, 30, 0, 0), u'3.76.54', u'\u9650\u5236\u6027\u62db\u6a19(\u7d93\u516c\u958b\u8a55\u9078\u6216\u516c\u958b\u5fb5\u6c42)', u'\u81fa\u6771\u7e23\u653f\u5e9c', u'<\u52de\u52d9\u985e>8673\u7d9c\u5408\u5de5\u7a0b\u670d\u52d9', datetime.datetime(2016, 2, 24, 0, 0), u'\u5bcc\u5ca1\u6f01\u6e2f\u707d\u5f8c\u5fa9\u5efa\u5de5\u7a0b\u8a2d\u8a08\u53ca\u76e3\u9020\u5de5\u4f5c', u'\u975e\u5c6c\u611b\u53f0\u5341\u4e8c\u9805\u8a08\u756b', u'\u6c7a\u6a19\u516c\u544a', 6809524, 6182331, u'104150330477', u'\u6e96\u7528\u6700\u6709\u5229\u6a19']

# %%
import sqlite3

sql = 'insert into Tender_awards ({}) values({})'
con = sqlite3.connect("test.sqlite") 
cur = con.cursor() 

# insert into Tender_awards (c1, c2, c3...) values(?,?,?)
element = get_response_element('C:/Users/BIG DATA/Desktop/python_homework2/51760773_104150330477.text')
dic = get_award_info_dic(element)
columns =  ', '.join(dic.keys())
placeholders = ','.join(len(dic) * '?')
cur.execute(sql.format(columns, placeholders), dic.values())
con.commit()
con.close()

# %%
import os
path = 'C:/Users/BIG DATA/Desktop/python_homework2/'
os.listdir(path)
for f in os.listdir(path):
    print path + f
# Out:
# C:/Users/BIG DATA/Desktop/python_homework2/51760773_104150330477.text
# C:/Users/BIG DATA/Desktop/python_homework2/51774470_1040226-1-5.text
# C:/Users/BIG DATA/Desktop/python_homework2/51779050_104-191-1.text
# C:/Users/BIG DATA/Desktop/python_homework2/51784164_105traffic013.text
# C:/Users/BIG DATA/Desktop/python_homework2/51784165_km105-0104.text
# C:/Users/BIG DATA/Desktop/python_homework2/51784166_ED05002E014.text
# C:/Users/BIG DATA/Desktop/python_homework2/51784168_1050101.text
# C:/Users/BIG DATA/Desktop/python_homework2/51784170_105CY19.text
# C:/Users/BIG DATA/Desktop/python_homework2/51784171_105traffic011.text
# C:/Users/BIG DATA/Desktop/python_homework2/51784174_105traffic012.text
# C:/Users/BIG DATA/Desktop/python_homework2/51784176_1050203.text
# C:/Users/BIG DATA/Desktop/python_homework2/51784195_sgps1050202.text
# C:/Users/BIG DATA/Desktop/python_homework2/51784196_1050008.text
# C:/Users/BIG DATA/Desktop/python_homework2/51785410_TECROUSA105002.text
# C:/Users/BIG DATA/Desktop/python_homework2/51785493_10502.text
# C:/Users/BIG DATA/Desktop/python_homework2/51785515_1050130.text
# C:/Users/BIG DATA/Desktop/python_homework2/51785538_105-02.text
# C:/Users/BIG DATA/Desktop/python_homework2/51785542_105-10.text
# C:/Users/BIG DATA/Desktop/python_homework2/51785552_105-12.text
# C:/Users/BIG DATA/Desktop/python_homework2/51785562_10502.text
# C:/Users/BIG DATA/Desktop/python_homework2/51785582_LMES105-2.text
# C:/Users/BIG DATA/Desktop/python_homework2/51785606_1050217.text
# C:/Users/BIG DATA/Desktop/python_homework2/51785619_105-2-3-1-0018.text
# C:/Users/BIG DATA/Desktop/python_homework2/51785645_B201602.text
# C:/Users/BIG DATA/Desktop/python_homework2/51785695_10501A008.text
# C:/Users/BIG DATA/Desktop/python_homework2/51785762_1050215.text
# C:/Users/BIG DATA/Desktop/python_homework2/51785767_105011.text
# C:/Users/BIG DATA/Desktop/python_homework2/51785854_10508.text
# C:/Users/BIG DATA/Desktop/python_homework2/51785934_1050224ED.text

# %%
def insert_award_info (cur, data_dic, filename):
    file_param=filename.split(".txt")[0].split("_")
    pkAtmMain=file_param[0]
    data_dic['pkAtmMain']=pkAtmMain
    columns = ', '.join(data_dic.keys())
    placeholders = ', '.join('?' * len(data_dic))
    sql = 'INSERT INTO Tender_awards ({}) VALUES ({})'.format(columns, placeholders)	
    cur.execute(sql, data_dic.values())

# %%
import os
import sqlite3

sql = 'insert into Tender_awards ({}) values({})'
con = sqlite3.connect("test.sqlite") 
cur = con.cursor() 
path = 'C:/Users/BIG DATA/Desktop/python_homework2/'
os.listdir(path)
for f in os.listdir(path):
    element = get_response_element(path + f)
    dic = get_award_info_dic(element)
    insert_award_info(cur, dic, f)
    con.commit()
con.close()

# %% [markdown]
# ###  Sqlite Manager的試用

# %%
import sqlite3
db = sqlite3.connect('test.sqlite')  #會在所處位置之下產生一個test.sqlite資料庫連線檔案
cur = db.cursor()    #cursor()是一個游標的概念，例如：指向資料庫的第一列
#建立table及欄位名稱
cur.execute('''CREATE TABLE IF NOT EXISTS Tender_awards(
                id INTEGER PRIMARY KEY,
                pkAtmMain TEXT,
                procuring_entity TEXT,
                entity_code TEXT,
                attr_of_procurement TEXT,
                opening_date DATETIME,
                procurement_type TEXT,
                tender_awarding_type TEXT,
                project_type TEXT,
                subject_of_procurement TEXT,
                job_number TEXT,
                budget_value BIGINTEGER,
                attr_of_tender_awarding TEXT,
                floor_price_value BIGINTEGER,
                tender_awarding_announce_date DATETIME,
                tender_awarding_date DATETIME,
                total_tender_awarding_value BIGINTEGER
                )''')
db.close()   #要記得關閉資料庫

# %%
import sqlite3
#建立一個新的PhoneAddress table，並把資料匯入
#與剛剛建立的資料庫建立連線
con = sqlite3.connect("test.sqlite") 

cur = con.cursor() 
cur.execute("DROP TABLE IF EXISTS PhoneAddress")  # Drop Table If Exisits 
cur.execute("CREATE TABLE PhoneAddress(phone CHAR(10) PRIMARY KEY, address TEXT, name TEXT unique, age INT NOT NULL)") 
cur.execute("INSERT INTO PhoneAddress VALUES('0912173381','United State','Jhon Doe',53)") 
cur.execute("INSERT INTO PhoneAddress VALUES('0928375018','Tokyo Japan','MuMu Cat',6)") 
cur.execute("INSERT INTO PhoneAddress VALUES('0957209108','Taipei','Richard',29)") 
con.commit() # 下完指令要記得commit
#cur.execute("SELECT phone,address FROM PhoneAddress") 
#data = cur.fetchall() 
#    for rec in data: 
#        print rec[0], rec[1] 
con.close()

# %%
import sqlite3

con = sqlite3.connect("test.sqlite") 

cur = con.cursor() 

cur.execute("SELECT phone,address FROM PhoneAddress") 
data = cur.fetchone() # fetch one row at a time 選擇第一行印出
print data
data2 = cur.fetchone() #在選擇一行印出，但因為剛剛第一行印過，指標已經到第二行，所以會印第二行的東西
print data2
data2 = cur.fetchall() # fetch all rows at a time  #把其餘剩下的全部印出，並放在陣列裡面
print data2
con.close()
# Out:
# (u'0912173381', u'United State')
# (u'0928375018', u'Tokyo Japan')
# [(u'0957209108', u'Taipei')]
