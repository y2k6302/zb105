# %%
#把使用的套件都匯入
import re
from pymongo import MongoClient 
import numpy as np
import re
import jieba
jieba.set_dictionary('E:/dics/dict.txt.big.txt')  #切換至中文繁體字庫
jieba.load_userdict("E:/dics/dict_keyw.txt")       #加入自建詞庫

#預設就是自己
client = MongoClient('10.120.28.12',27017)
database = client['test']
collection =database['test']
# Out:
# Building prefix dict from E:\dics\dict.txt.big.txt ...
# Loading model from cache c:\users\bigdat~1\appdata\local\temp\jieba.u56ec63d90e89b3354142c30b3eb89a90.cache
# Loading model cost 0.489 seconds.
# Prefix dict has been built succesfully.

# %%
for post in collection.find():
    #print len(post['pos'])
    print len(post['tfidf'])
# Out:
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# 30
# ...

# %%
json = []
for post in collection.find():
    dic = {
        'date':post['date'],
        'pos_num':len(post['pos']),
        'neg_num':len(post['neg']),      
    }
    json.append(dic)
print len(json)
print json[0]
# Out:
# 7135
# {'date': u'20130101', 'pos_num': 19, 'neg_num': 4}

# %%
pos_neg_json = []
for post in collection.find():
    dic1 = {
        'Date':post['date'],
        'Hot':len(post['pos']),
        'Channel':"Positive",      
    }
    dic2 = {
        'Date':post['date'],
        'Hot':len(post['neg']),
        'Channel':"Negative",      
    }
    pos_neg_json.append(dic1)
    pos_neg_json.append(dic2)
print len(pos_neg_json)
print pos_neg_json[1]
# Out:
# 14270
# {'Date': u'20130101', 'Hot': 4, 'Channel': 'Negative'}

# %%
print type(pos_neg_json)
# Out:
# <type 'list'>
