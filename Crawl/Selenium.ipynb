# %% [markdown]
# ## 重點提示

# %%
#原始部份
#driver = self.driver
#driver.implicitly_wait(30)
#self.base.url = 'dasdadasdsa'
#driver.get(self.base_url + "/FJUD/")

#要改成的部分
#driver = webdriver.Firefox()
#driver.implicitly_wait(30)
#base_url = "http://jirs.judicial.gov.tw"   
#driver.get(base_url + "/FJUD/FJUDQRY01_1.aspx")

#作完動作就要soup一下，把要的內容抓下來
#soup = BeautifulSoup(driver.page_source)

# %% [markdown]
# ## 科技報橘爬取

# %%
#成功版本
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import time

#把所有的self都刪掉
driver = webdriver.Firefox()    #要用甚麼瀏覽器開啟
driver.implicitly_wait(30)      #必須要有
base_url = "http://buzzorange.com/"    #起始頁面的url
driver.get(base_url + "/techorange/")  #必須要有
for i in range(0,5):
    driver.find_element_by_css_selector("i.icon-plus").click()   #紀錄的動作
    time.sleep(1)                                                #跑完一次睡一秒
soup = BeautifulSoup(driver.page_source)                         #超級重要，會把該動作執行前的頁面記錄下來，可寫在迴圈內或外面
hrefs=soup.select('a')
for href in hrefs:
    print href.text
# Out:
# 商業策略
# 職涯
# 生活
# 工程師
# 創業家精神
# 設計
# 數位行銷
# Google
# Apple
#
#
# 和同業慷慨分享 15 年研發菁華的台灣老闆：我們要打造台灣產業高品質的國際形象
#
# 一秒分辨專業 PM 靠的不是看年資，而是有沒有趁早掌握 PM 三大關鍵力
#
# Google AlphaGo 主要開發者黃士傑：台灣人才技術不弱，就是缺乏信心
#
# 【胡一天】金融科技與貨幣超限戰
#
# 嗶嗶嗶電動車業者注意！Tesla 進軍台灣了，一口氣狂開 11 工作職缺組建團隊
# 和同業慷慨分享 15 年研發菁華的台灣老闆：我們要打造台灣產業高品質的國際形象
# 一秒分辨專業 PM 靠的不是看年資，而是有沒有趁早掌握 PM 三大關鍵力
# Google AlphaGo 主要開發者黃士傑：台灣人才技術不弱，就是缺乏信心
# 【胡一天】金融科技與貨幣超限戰
# 嗶嗶嗶電動車業者注意！Tesla 進軍台灣了，一口氣狂開 11 工作職缺組建團隊
#
# 和同業慷慨分享 15 年研發菁華的台灣老闆：我們要打造台灣產業高品質的國際形象
# 今周刊
# 創業家精神
# 商業策略
#
# 631
#
#
# 一秒分辨專業 PM 靠的不是看年資，而是有沒有趁早掌握 PM 三大關鍵力
# TO 精選觀點
# PM
#
# 386
# 3
#
# 車商科技廠都在埋頭研究自動車，但現實世界要怎麼調整才能讓它順利上路？
# TO 精選觀點
# 汽車
#
# 23
# 1
#
# Google AlphaGo 主要開發者黃士傑：台灣人才技術不弱，就是缺乏信心
# 鄒昀倢
# 台灣
# 工程師
#
# 2124
# 7
#
# 【橘子課程】科技公司 PM 注意！這些是你職涯必修的 8 堂課
# 沈孟學
#
# 40
#
#
# 【胡一天】金融科技與貨幣超限戰
# TO 精選觀點
# fintech
# 區塊鏈
# 貨幣
#
# 19
#
#
# 是否處於公司人事變動的暴風圈？一眼看出老闆醞釀裁員的八大徵兆
# TECH2IPO
#
# 68
# 2
#
# 一樣花大錢，你的 4G 卻慢半拍？快來實測！電信三雄誰飆速？誰龜速？赤裸現形！
# Speed test
#
# 983
# 2
#
# 來開發個能自動寫程式的程式吧！但這樣工程師不就失業了嗎？
# 36氪
# ...

# %%
#原始版本
# -*- coding: utf-8 -*-
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re

class 22(unittest.TestCase):
    def setUp(self):
        self.driver = webdriver.Firefox()
        self.driver.implicitly_wait(30)
        self.base_url = "http://buzzorange.com/"
        self.verificationErrors = []
        self.accept_next_alert = True
    
    def test_22(self):
        driver = self.driver
        driver.get(self.base_url + "/techorange/")
        driver.find_element_by_css_selector("i.icon-plus").click()
        driver.find_element_by_css_selector("i.icon-plus").click()
        
#以下部分都要刪掉        
    def is_element_present(self, how, what):
        try: self.driver.find_element(by=how, value=what)
        except NoSuchElementException as e: return False
        return True
    
    def is_alert_present(self):
        try: self.driver.switch_to_alert()
        except NoAlertPresentException as e: return False
        return True
    
    def close_alert_and_get_its_text(self):
        try:
            alert = self.driver.switch_to_alert()
            alert_text = alert.text
            if self.accept_next_alert:
                alert.accept()
            else:
                alert.dismiss()
            return alert_text
        finally: self.accept_next_alert = True
    
    def tearDown(self):
        self.driver.quit()
        self.assertEqual([], self.verificationErrors)

if __name__ == "__main__":
    unittest.main()
# Out:
# 商業策略
# 職涯
# 生活
# 工程師
# 創業家精神
# 設計
# 數位行銷
# Google
# Apple
#
#
# 和同業慷慨分享 15 年研發菁華的台灣老闆：我們要打造台灣產業高品質的國際形象
#
# 一秒分辨專業 PM 靠的不是看年資，而是有沒有趁早掌握 PM 三大關鍵力
#
# Google AlphaGo 主要開發者黃士傑：台灣人才技術不弱，就是缺乏信心
#
# 【胡一天】金融科技與貨幣超限戰
#
# 嗶嗶嗶電動車業者注意！Tesla 進軍台灣了，一口氣狂開 11 工作職缺組建團隊
# 和同業慷慨分享 15 年研發菁華的台灣老闆：我們要打造台灣產業高品質的國際形象
# 一秒分辨專業 PM 靠的不是看年資，而是有沒有趁早掌握 PM 三大關鍵力
# Google AlphaGo 主要開發者黃士傑：台灣人才技術不弱，就是缺乏信心
# 【胡一天】金融科技與貨幣超限戰
# 嗶嗶嗶電動車業者注意！Tesla 進軍台灣了，一口氣狂開 11 工作職缺組建團隊
#
# 和同業慷慨分享 15 年研發菁華的台灣老闆：我們要打造台灣產業高品質的國際形象
# 今周刊
# 創業家精神
# 商業策略
#
# 631
#
#
# 一秒分辨專業 PM 靠的不是看年資，而是有沒有趁早掌握 PM 三大關鍵力
# TO 精選觀點
# PM
#
# 386
# 3
#
# 車商科技廠都在埋頭研究自動車，但現實世界要怎麼調整才能讓它順利上路？
# TO 精選觀點
# 汽車
#
# 23
# 1
#
# Google AlphaGo 主要開發者黃士傑：台灣人才技術不弱，就是缺乏信心
# 鄒昀倢
# 台灣
# 工程師
#
# 2124
# 7
#
# 【橘子課程】科技公司 PM 注意！這些是你職涯必修的 8 堂課
# 沈孟學
#
# 40
#
#
# 【胡一天】金融科技與貨幣超限戰
# TO 精選觀點
# fintech
# 區塊鏈
# 貨幣
#
# 19
#
#
# 是否處於公司人事變動的暴風圈？一眼看出老闆醞釀裁員的八大徵兆
# TECH2IPO
#
# 68
# 2
#
# 一樣花大錢，你的 4G 卻慢半拍？快來實測！電信三雄誰飆速？誰龜速？赤裸現形！
# Speed test
#
# 983
# 2
#
# 來開發個能自動寫程式的程式吧！但這樣工程師不就失業了嗎？
# 36氪
# ...

# %% [markdown]
# ##  司法院參考

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import random

for y in begin_year:
    driver = webdriver.Firefox()
    driver.implicitly_wait(30)
    base_url = "http://buzzorange.com/techorange/"   
    driver.get(base_url + "/FJUD/FJUDQRY01_1.aspx")
    time.sleep(10)
    Select(driver.find_element_by_name("v_court")).select_by_visible_text(court[7])
    driver.find_elements_by_css_selector("input[type='radio'][value='V']")[0].click()
    driver.find_element_by_id("jt").clear()
    driver.find_element_by_id("jt").send_keys(u"保險")
    driver.find_element_by_name("dy1").clear()
    driver.find_element_by_name("dy1").send_keys(y)
    driver.find_element_by_name("dm1").clear()
    driver.find_element_by_name("dm1").send_keys("1")
    driver.find_element_by_name("dd1").clear()
    driver.find_element_by_name("dd1").send_keys("1")
    driver.find_element_by_name("dy2").clear()
    x=str(int(y)+1)
    driver.find_element_by_name("dy2").send_keys(x)
    driver.find_element_by_name("dm2").clear()
    driver.find_element_by_name("dm2").send_keys("1")
    driver.find_element_by_name("dd2").clear()
    driver.find_element_by_name("dd2").send_keys("1")
    driver.find_element_by_name("Button").click()
    r = random.randint(1,3)
    time.sleep(r)
    
    soup = BeautifulSoup(driver.page_source)
    
    hrefs = soup.select('a')
    href3=hrefs[2]
    a=href3
    b=href3.text   
    driver.find_element_by_link_text(b).click()
    r = random.randint(1,3)
    time.sleep(r)
    soup = BeautifulSoup(driver.page_source)
    z+=1
    #name = soup.select('span')[4].text.encode('utf-8')
    f = open('C:/Users/BIG DATA/Desktop/crawler/{}.txt'.format(z), 'w')
    f.write(soup.text.encode('utf-8'))
    f.close()
    hrefs = soup.select('a')
    li = []
    for href in hrefs:
        li.append(href.text)
    
    while u'\u4e0b\u4e00\u7b46' in li:
        z+=1
        driver.find_element_by_link_text(u"下一筆").click()
        r = random.randint(1,3)
        time.sleep(r)
        soup = BeautifulSoup(driver.page_source)
        #name = soup.select('span')[4].text.encode('utf-8')
        f = open('C:/Users/BIG DATA/Desktop/crawler/{}.txt'.format(z), 'w')
        f.write(soup.text.encode('utf-8'))
        f.close()
        hrefs = soup.select('a')
        li = []
        for href in hrefs:
            li.append(href.text)
        if not u'\u4e0b\u4e00\u7b46' in li:
            break
        
    print y+'success'
print 'all success'
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-571f6b48cf73> in <module>()
#      54     z+=1
#      55     #name = soup.select('span')[4].text.encode('utf-8')
# ---> 56     f = open('C:/Users/BIG DATA/Desktop/crawler/{}.txt'.format(z), 'w')
#      57     f.write(soup.text.encode('utf-8'))
#      58     f.close()
#
# IOError: [Errno 2] No such file or directory: 'C:/Users/BIG DATA/Desktop/crawler/1.txt'
